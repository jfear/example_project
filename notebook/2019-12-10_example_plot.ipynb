# %% [markdown]
# # Example Notebook 1

# %% [markdown]
# This is just a quick example of making a plot and showing how it is stored in the notebook.

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([[0, 0], [1, 1]])
ax = plt.gca()
ax.set(xlabel="X-Axis", ylabel="Y-Axis", title="Title");
